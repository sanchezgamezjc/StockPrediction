# %%
import yfinance as yf
import datetime as dt
import pandas_datareader as pdr
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

# %% [markdown]
# ## Descarga datos y creación dataset

# %%
sample_per = 200
stock = 'EURGBP=X'

end = dt.date.today()- dt.timedelta(days=2)
start = end - dt.timedelta(days=(sample_per))
interval = '1h'

# %%
database = yf.download(stock, start=start, end=end, interval=interval)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Creamos indicadores
database['200ma'] = database['Adj Close'].ewm(span=200).mean()
database['50ma'] = database['Adj Close'].ewm(span=50, adjust=False).mean()
database['20ma'] = database['Adj Close'].ewm(span=20, adjust=False).mean()


#Generamos una copia, añadimos la columna de diferencia y eliminamos valores NaN
db = database.copy()

db['Dif'] = db['Adj Close'].diff()

db.dropna(inplace=True)

# %%
db['log_ret'] = db['Adj Close'].pct_change()


# Creamos el indicador Up_Down segun si es positivo o negativo (sube o baja precio)
lista =[]
for index, row in db.iterrows():
    if row['log_ret'] > 0:
        lista.append(1)
    else:
        lista.append(-1)

serie = pd.Series(lista, index = db.index)

#Lo añadimos al DataFrame y nos quedamos con las columnas que nos interesan
db['Up_Down'] = serie


data = db[['log_ret', '200ma', '50ma', '20ma','Up_Down']].copy()

data.dropna(inplace=True)

data
# Out:
#                             log_ret     200ma      50ma      20ma  Up_Down
# 2021-02-10 01:00:00+00:00  0.000068  0.876953  0.876995  0.876988        1
# 2021-02-10 02:00:00+00:00  0.000068  0.876970  0.876996  0.876991        1
# 2021-02-10 03:00:00+00:00  0.000296  0.877033  0.877007  0.877018        1
# 2021-02-10 04:00:00+00:00  0.000137  0.877096  0.877022  0.877055        1
# 2021-02-10 05:00:00+00:00 -0.000160  0.877120  0.877032  0.877074       -1
# ...                             ...       ...       ...       ...      ...
# 2021-08-27 18:00:00+01:00  0.000257  0.855332  0.857018  0.857253        1
# 2021-08-27 19:00:00+01:00 -0.000105  0.855345  0.857003  0.857194       -1
# 2021-08-27 20:00:00+01:00  0.000467  0.855362  0.857004  0.857178        1
# 2021-08-27 21:00:00+01:00 -0.000910  0.855371  0.856974  0.857090       -1
# 2021-08-27 22:00:00+01:00  0.000724  0.855386  0.856970  0.857069        1
#
# [3403 rows x 5 columns]

# %%
data['Up_Down'] = data['Up_Down'].shift(-1)
data.dropna(inplace=True)
data
# Out:
#                             log_ret     200ma      50ma      20ma  Up_Down
# 2021-02-10 01:00:00+00:00  0.000068  0.876953  0.876995  0.876988      1.0
# 2021-02-10 02:00:00+00:00  0.000068  0.876970  0.876996  0.876991      1.0
# 2021-02-10 03:00:00+00:00  0.000296  0.877033  0.877007  0.877018      1.0
# 2021-02-10 04:00:00+00:00  0.000137  0.877096  0.877022  0.877055     -1.0
# 2021-02-10 05:00:00+00:00 -0.000160  0.877120  0.877032  0.877074      1.0
# ...                             ...       ...       ...       ...      ...
# 2021-08-27 17:00:00+01:00 -0.000105  0.855319  0.857030  0.857309      1.0
# 2021-08-27 18:00:00+01:00  0.000257  0.855332  0.857018  0.857253     -1.0
# 2021-08-27 19:00:00+01:00 -0.000105  0.855345  0.857003  0.857194      1.0
# 2021-08-27 20:00:00+01:00  0.000467  0.855362  0.857004  0.857178     -1.0
# 2021-08-27 21:00:00+01:00 -0.000910  0.855371  0.856974  0.857090      1.0
#
# [3402 rows x 5 columns]

# %% [markdown]
# ## Preparacion datos para el LSTM

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3402 entries, 2021-02-10 01:00:00+00:00 to 2021-08-27 21:00:00+01:00
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   log_ret  3402 non-null   float64
#  1   200ma    3402 non-null   float64
#  2   50ma     3402 non-null   float64
#  3   20ma     3402 non-null   float64
#  4   Up_Down  3402 non-null   float64
# dtypes: float64(5)
# memory usage: 159.5 KB

# %%
#Escalamos los valores con un MinMaxScaler
values = data.values

scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(values)

values = scaled


#Dividimos los datos entre train y test
train, test = train_test_split(values, test_size=0.2, shuffle=False)


#Separamos los inputs de los outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]


#Generamos el reshape para poder incluir los valores en el modelo LSTM
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (2721, 1, 4) (2721,) (681, 1, 4) (681,)

# %% [markdown]
# ## Creamos el modelo

# %%
#Generamos arquitectura del modelo
model = Sequential()
model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(50, return_sequences=True))
model.add(Dropout(0.2))

model.add(Dense(1, activation='tanh'))

model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_7 (LSTM)                (None, 1, 50)             11000
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 50)             0
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 1, 50)             20200
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1, 50)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 1)              51
# =================================================================
# Total params: 31,251
# Trainable params: 31,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Entrenamos el modelo
history = model.fit(train_X, train_y, epochs=50, batch_size = 280, validation_data=(test_X, test_y), verbose=2, shuffle=True)
# Out:
# Epoch 1/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9934
# Epoch 2/50
# 10/10 - 0s - loss: 0.9958 - val_loss: 0.9934
# Epoch 3/50
# 10/10 - 0s - loss: 0.9966 - val_loss: 0.9935
# Epoch 4/50
# 10/10 - 0s - loss: 0.9961 - val_loss: 0.9935
# Epoch 5/50
# 10/10 - 0s - loss: 0.9964 - val_loss: 0.9935
# Epoch 6/50
# 10/10 - 0s - loss: 0.9958 - val_loss: 0.9935
# Epoch 7/50
# 10/10 - 0s - loss: 0.9967 - val_loss: 0.9935
# Epoch 8/50
# 10/10 - 0s - loss: 0.9965 - val_loss: 0.9935
# Epoch 9/50
# 10/10 - 0s - loss: 0.9970 - val_loss: 0.9935
# Epoch 10/50
# 10/10 - 0s - loss: 0.9965 - val_loss: 0.9936
# Epoch 11/50
# 10/10 - 0s - loss: 0.9963 - val_loss: 0.9936
# Epoch 12/50
# 10/10 - 0s - loss: 0.9969 - val_loss: 0.9936
# Epoch 13/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9936
# Epoch 14/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9937
# Epoch 15/50
# 10/10 - 0s - loss: 0.9951 - val_loss: 0.9936
# Epoch 16/50
# 10/10 - 0s - loss: 0.9965 - val_loss: 0.9936
# Epoch 17/50
# 10/10 - 0s - loss: 0.9966 - val_loss: 0.9937
# Epoch 18/50
# 10/10 - 0s - loss: 0.9966 - val_loss: 0.9935
# Epoch 19/50
# 10/10 - 0s - loss: 0.9958 - val_loss: 0.9936
# Epoch 20/50
# 10/10 - 0s - loss: 0.9960 - val_loss: 0.9935
# Epoch 21/50
# 10/10 - 0s - loss: 0.9964 - val_loss: 0.9934
# Epoch 22/50
# 10/10 - 0s - loss: 0.9965 - val_loss: 0.9935
# Epoch 23/50
# 10/10 - 0s - loss: 0.9964 - val_loss: 0.9936
# Epoch 24/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9936
# Epoch 25/50
# 10/10 - 0s - loss: 0.9960 - val_loss: 0.9935
# Epoch 26/50
# 10/10 - 0s - loss: 0.9965 - val_loss: 0.9936
# Epoch 27/50
# 10/10 - 0s - loss: 0.9963 - val_loss: 0.9937
# Epoch 28/50
# 10/10 - 0s - loss: 0.9962 - val_loss: 0.9936
# Epoch 29/50
# 10/10 - 0s - loss: 0.9948 - val_loss: 0.9937
# Epoch 30/50
# 10/10 - 0s - loss: 0.9956 - val_loss: 0.9936
# Epoch 31/50
# 10/10 - 0s - loss: 0.9960 - val_loss: 0.9936
# Epoch 32/50
# 10/10 - 0s - loss: 0.9955 - val_loss: 0.9935
# Epoch 33/50
# 10/10 - 0s - loss: 0.9964 - val_loss: 0.9935
# Epoch 34/50
# 10/10 - 0s - loss: 0.9957 - val_loss: 0.9935
# Epoch 35/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9935
# Epoch 36/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9936
# Epoch 37/50
# 10/10 - 0s - loss: 0.9961 - val_loss: 0.9934
# Epoch 38/50
# 10/10 - 0s - loss: 0.9963 - val_loss: 0.9935
# Epoch 39/50
# 10/10 - 0s - loss: 0.9955 - val_loss: 0.9936
# Epoch 40/50
# 10/10 - 0s - loss: 0.9960 - val_loss: 0.9936
# Epoch 41/50
# 10/10 - 0s - loss: 0.9957 - val_loss: 0.9936
# Epoch 42/50
# 10/10 - 0s - loss: 0.9958 - val_loss: 0.9935
# Epoch 43/50
# 10/10 - 0s - loss: 0.9958 - val_loss: 0.9936
# Epoch 44/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9936
# Epoch 45/50
# 10/10 - 0s - loss: 0.9959 - val_loss: 0.9936
# Epoch 46/50
# 10/10 - 0s - loss: 0.9957 - val_loss: 0.9937
# Epoch 47/50
# 10/10 - 0s - loss: 0.9966 - val_loss: 0.9937
# Epoch 48/50
# 10/10 - 0s - loss: 0.9968 - val_loss: 0.9938
# Epoch 49/50
# 10/10 - 0s - loss: 0.9964 - val_loss: 0.9938
# Epoch 50/50
# 10/10 - 0s - loss: 0.9966 - val_loss: 0.9938

# %%
#Generamos plot con los resultados
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
yhat = model.predict(test_X)

# %%
df = pd.DataFrame({'yhat':yhat.reshape(yhat.shape[0],), 'test_y':test_y})

# %%
df['corr'] = df['yhat']*df['test_y']

# %%
df
# Out:
#          yhat  test_y      corr
# 0   -0.048425    -1.0  0.048425
# 1    0.020491     1.0  0.020491
# 2   -0.133003     1.0 -0.133003
# 3   -0.078594     1.0 -0.078594
# 4   -0.055907     1.0 -0.055907
# ..        ...     ...       ...
# 676 -0.007144     1.0 -0.007144
# 677 -0.018424    -1.0  0.018424
# 678 -0.006377     1.0 -0.006377
# 679 -0.024667    -1.0  0.024667
# 680  0.020216     1.0  0.020216
#
# [681 rows x 3 columns]
