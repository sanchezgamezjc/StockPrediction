# %%
import yfinance as yf
import datetime as dt
import pandas_datareader as pdr
import pandas as pd
import pandas_ta as pta
import matplotlib.pyplot as plt
import numpy as np


from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Conv1D, Conv2D, Flatten, MaxPooling1D

# %%
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path+"\\FileBase")

from root_functions import add_indicators, up_down, full_prediction, result

# %% [markdown]
# ## Descarga datos y creación dataset

# %%
sample_per = 400
stock = 'EURGBP=X'

end = dt.date.today()- dt.timedelta(days=2)
start = end - dt.timedelta(days=(sample_per))
interval = '1h'

# %%
database = yf.download(stock, start=start, end=end, interval=interval)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Añadimos indicadores
data_base = add_indicators(database)

#Añadimos columna up_down
data_base = up_down(data_base)

# %%
data_base['Up_Down'] = data_base['Up_Down'].shift(-1)

# %%
data_base.dropna(inplace=True)

# %%
data = data_base.iloc[:,4:]

data = data[['Adj Close', '200ema', '50ema', '20ema', 'PSAR']]


cols = data.columns

# %%
data
# Out:
#                            Adj Close    200ema     50ema     20ema      PSAR  \
# 2020-07-28 09:00:00+01:00    0.91002  0.912072  0.911659  0.911917 -0.913891
# 2020-07-28 10:00:00+01:00    0.91113  0.912041  0.911639  0.911842 -0.913724
# 2020-07-28 11:00:00+01:00    0.91122  0.912014  0.911622  0.911783 -0.913446
# 2020-07-28 12:00:00+01:00    0.90989  0.911945  0.911554  0.911602 -0.913184
# 2020-07-28 13:00:00+01:00    0.91047  0.911899  0.911512  0.911495 -0.912939
# ...                              ...       ...       ...       ...       ...
# 2021-08-27 17:00:00+01:00    0.85650  0.855319  0.857030  0.857309 -0.858017
# 2021-08-27 18:00:00+01:00    0.85672  0.855332  0.857018  0.857253 -0.857829
# 2021-08-27 19:00:00+01:00    0.85663  0.855345  0.857003  0.857194 -0.857656
# 2021-08-27 20:00:00+01:00    0.85703  0.855362  0.857004  0.857178 -0.857498
# 2021-08-27 21:00:00+01:00    0.85625  0.855371  0.856974  0.857090  0.855670
#
#                                 ATR
# 2020-07-28 09:00:00+01:00  0.001438
# 2020-07-28 10:00:00+01:00  0.001505
# 2020-07-28 11:00:00+01:00  0.001495
# 2020-07-28 12:00:00+01:00  0.001573
# 2020-07-28 13:00:00+01:00  0.001562
# ...                             ...
# 2021-08-27 17:00:00+01:00  0.000999
# 2021-08-27 18:00:00+01:00  0.000976
# 2021-08-27 19:00:00+01:00  0.000935
# 2021-08-27 20:00:00+01:00  0.000917
# 2021-08-27 21:00:00+01:00  0.000958
#
# [6723 rows x 6 columns]

# %% [markdown]
# ## Preparacion datos para el LSTM

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6723 entries, 2020-07-28 09:00:00+01:00 to 2021-08-27 21:00:00+01:00
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Adj Close  6723 non-null   float64
#  1   200ema     6723 non-null   float64
#  2   50ema      6723 non-null   float64
#  3   20ema      6723 non-null   float64
#  4   PSAR       6723 non-null   float64
#  5   ATR        6723 non-null   float64
# dtypes: float64(6)
# memory usage: 367.7 KB

# %%
#Escalamos los valores con un MinMaxScaler
values = data.values

scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(values)

values = scaled


#Dividimos los datos entre train y test
train, val = train_test_split(values, test_size=0.2, shuffle=False)

#Dividimos datos validation entre validation y test
val, test = train_test_split(val, test_size=0.5, shuffle=False)

#Separamos los inputs de los outputs
train_X, train_y = train[:, 1:], train[:,0]
val_X, val_y = val[:, 1:], val[:,0]
test_X, test_y = test[:, 1:], test[:, 0]


#Generamos el reshape para poder incluir los valores en el modelo LSTM
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape)
# Out:
# (5378, 1, 5) (5378,) (672, 1, 5) (672,) (673, 1, 5) (673,)

# %% [markdown]
# ## Creamos el modelo

# %%
#Generamos arquitectura del modelo
model = Sequential()

model.add(LSTM(64,  return_sequences=True, input_shape=(train_X.shape[1], train_X.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(128, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(256, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(512, activation='tanh', return_sequences=True))
model.add(Dropout(0.2))

#model.add(LSTM(1024, activation='relu', return_sequences=True))
#model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))

model.compile(loss='mse', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 1, 64)             17920
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 64)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 128)            98816
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 128)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 256)            394240
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 256)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 1, 512)            1574912
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 512)            0
# _________________________________________________________________
# dense (Dense)                (None, 1, 1)              513
# =================================================================
# Total params: 2,086,401
# Trainable params: 2,086,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Entrenamos el modelo
history = model.fit(train_X, train_y, epochs=5, batch_size = 128, validation_data=(val_X, val_y), verbose=1, shuffle=False)
# Out:
# Epoch 1/5
# 43/43 [==============================] - 9s 65ms/step - loss: 0.2166 - val_loss: 0.0064
# Epoch 2/5
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0742 - val_loss: 0.1626
# Epoch 3/5
# 43/43 [==============================] - 1s 21ms/step - loss: 0.0267 - val_loss: 0.0050
# Epoch 4/5
# 43/43 [==============================] - 1s 19ms/step - loss: 0.0116 - val_loss: 0.0064
# Epoch 5/5
# 43/43 [==============================] - 1s 20ms/step - loss: 0.0118 - val_loss: 0.0042

# %%
#Generamos plot con los resultados
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %% [markdown]
# ## Resultados con valores de test

# %%
# make a prediction
yhat = model.predict(test_X)

# %%
inv_y, inv_yhat = full_prediction(yhat, test_X, test_y)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_y = scaler.inverse_transform(inv_y)


inv_yhat_df = pd.DataFrame(data=inv_yhat, columns=cols)
inv_y_df = pd.DataFrame(data=inv_y, columns=cols)

# %%
inv_y_df['log_ret'] = inv_y_df['Adj Close'].pct_change()

# %%
inv_yhat_df['log_ret'] = inv_yhat_df['Adj Close'].pct_change()

# %%
inv_y_df
# Out:
#      Adj Close    200ema     50ema     20ema      PSAR       ATR   log_ret
# 0      0.86485  0.857445  0.861132  0.863532 -0.866960  0.001508       NaN
# 1      0.86400  0.857510  0.861245  0.863577 -0.866889  0.001501 -0.000983
# 2      0.86503  0.857585  0.861393  0.863715 -0.866819  0.001494  0.001192
# 3      0.86467  0.857655  0.861521  0.863806 -0.866751  0.001452 -0.000416
# 4      0.86444  0.857723  0.861636  0.863867 -0.866684  0.001386 -0.000266
# ..         ...       ...       ...       ...       ...       ...       ...
# 668    0.85650  0.855319  0.857030  0.857309 -0.858017  0.000999 -0.000105
# 669    0.85672  0.855332  0.857018  0.857253 -0.857829  0.000976  0.000257
# 670    0.85663  0.855345  0.857003  0.857194 -0.857656  0.000935 -0.000105
# 671    0.85703  0.855362  0.857004  0.857178 -0.857498  0.000917  0.000467
# 672    0.85625  0.855371  0.856974  0.857090  0.855670  0.000958 -0.000910
#
# [673 rows x 7 columns]

# %%
inv_yhat_df
# Out:
#      Adj Close    200ema     50ema     20ema      PSAR       ATR   log_ret
# 0     0.863197  0.857445  0.861132  0.863532 -0.866960  0.001508       NaN
# 1     0.863238  0.857510  0.861245  0.863577 -0.866889  0.001501  0.000048
# 2     0.863321  0.857585  0.861393  0.863715 -0.866819  0.001494  0.000096
# 3     0.863282  0.857655  0.861521  0.863806 -0.866751  0.001452 -0.000045
# 4     0.863164  0.857723  0.861636  0.863867 -0.866684  0.001386 -0.000137
# ..         ...       ...       ...       ...       ...       ...       ...
# 668   0.858224  0.855319  0.857030  0.857309 -0.858017  0.000999 -0.000075
# 669   0.858144  0.855332  0.857018  0.857253 -0.857829  0.000976 -0.000094
# 670   0.858010  0.855345  0.857003  0.857194 -0.857656  0.000935 -0.000157
# 671   0.857959  0.855362  0.857004  0.857178 -0.857498  0.000917 -0.000059
# 672   0.858887  0.855371  0.856974  0.857090  0.855670  0.000958  0.001082
#
# [673 rows x 7 columns]

# %%
data.iloc[-inv_yhat_df.shape[0]:,:]
# Out:
#                            Adj Close    200ema     50ema     20ema      PSAR  \
# 2021-07-20 16:00:00+01:00    0.86485  0.857445  0.861132  0.863532 -0.866960
# 2021-07-20 17:00:00+01:00    0.86400  0.857510  0.861245  0.863577 -0.866889
# 2021-07-20 18:00:00+01:00    0.86503  0.857585  0.861393  0.863715 -0.866819
# 2021-07-20 19:00:00+01:00    0.86467  0.857655  0.861521  0.863806 -0.866751
# 2021-07-20 20:00:00+01:00    0.86444  0.857723  0.861636  0.863867 -0.866684
# ...                              ...       ...       ...       ...       ...
# 2021-08-27 17:00:00+01:00    0.85650  0.855319  0.857030  0.857309 -0.858017
# 2021-08-27 18:00:00+01:00    0.85672  0.855332  0.857018  0.857253 -0.857829
# 2021-08-27 19:00:00+01:00    0.85663  0.855345  0.857003  0.857194 -0.857656
# 2021-08-27 20:00:00+01:00    0.85703  0.855362  0.857004  0.857178 -0.857498
# 2021-08-27 21:00:00+01:00    0.85625  0.855371  0.856974  0.857090  0.855670
#
#                                 ATR
# 2021-07-20 16:00:00+01:00  0.001508
# 2021-07-20 17:00:00+01:00  0.001501
# 2021-07-20 18:00:00+01:00  0.001494
# 2021-07-20 19:00:00+01:00  0.001452
# 2021-07-20 20:00:00+01:00  0.001386
# ...                             ...
# 2021-08-27 17:00:00+01:00  0.000999
# 2021-08-27 18:00:00+01:00  0.000976
# 2021-08-27 19:00:00+01:00  0.000935
# 2021-08-27 20:00:00+01:00  0.000917
# 2021-08-27 21:00:00+01:00  0.000958
#
# [673 rows x 6 columns]

# %%
a = result(inv_yhat,inv_y)

# %%
a
# Out:
#          yhat        y  yhat_log     y_log           res  Up_Down
# 0    0.863197  0.86485       NaN       NaN           NaN       -1
# 1    0.863238  0.86400  0.000048 -0.000983 -4.704185e-08       -1
# 2    0.863321  0.86503  0.000096  0.001192  1.141866e-07        1
# 3    0.863282  0.86467 -0.000045 -0.000416  1.890476e-08        1
# 4    0.863164  0.86444 -0.000137 -0.000266  3.635422e-08        1
# ..        ...      ...       ...       ...           ...      ...
# 668  0.858224  0.85650 -0.000075 -0.000105  7.896821e-09        1
# 669  0.858144  0.85672 -0.000094  0.000257 -2.408837e-08       -1
# 670  0.858010  0.85663 -0.000157 -0.000105  1.643536e-08        1
# 671  0.857959  0.85703 -0.000059  0.000467 -2.772502e-08       -1
# 672  0.858887  0.85625  0.001082 -0.000910 -9.847379e-07       -1
#
# [673 rows x 6 columns]

# %%
print(a['Up_Down'].value_counts())
print()
per = a['Up_Down'].value_counts()[1]/(a['Up_Down'].value_counts()[1]+a['Up_Down'].value_counts()[-1])
print(f'% acierto: {per}')
# Out:
#  1    360
# -1    313
# Name: Up_Down, dtype: int64
#
# % acierto: 0.5349182763744428
