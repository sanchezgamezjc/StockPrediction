# %%
import yfinance as yf
import datetime as dt
import pandas_datareader as pdr
import pandas as pd
import pandas_ta as pta
import matplotlib.pyplot as plt
import numpy as np


from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Conv1D, Conv2D, Flatten, MaxPooling1D, BatchNormalization
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# %%
import sys

pth_apple = "/Users/josesanchez/Desktop/Code/GitHub/StockPrediction/FileBase"

sys.path.append(pth_apple)


from root_functions import add_indicators, up_down, full_prediction, full_prediction_binary, result

# %% [markdown]
# ## Descarga datos y creación dataset

# %%
sample_per = 400
stock = 'EURGBP=X'

end = dt.date.today()- dt.timedelta(days=2)
start = end - dt.timedelta(days=(sample_per))
interval = '1h'

# %%
database = yf.download(stock, start=start, end=end, interval=interval)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#Añadimos indicadores

ema1=200
ema2=50
ema3=20

data_base = add_indicators(database)

#Añadimos columna up_down
data_base = up_down(data_base)

#Listado indicadores
data_base.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', '200ema',
#        '50ema', '20ema', '14-high', '14-low', '%K', '%D', 'RSI', 'MACD',
#        'MACDh', 'MACDs', 'CCI', 'PSAR', 'BBl', 'BBm', 'BBu', 'BBb', 'BBp',
#        'ATR', 'log_ret', 'Up_Down'],
#       dtype='object')

# %%
#Hacemos un shift a la columna Up_Down para tener el signo de la tendencia de la siguiente vela
data_base['Up_Down'] = data_base['Up_Down'].shift(-1)

data_base.dropna(inplace=True)

# %%
#Filtramos las columnas que nos interesan para obtener el dataset de trabajo
db = data_base.copy()


data = db[['Up_Down',  'Adj Close','log_ret', '200ema', '50ema', '20ema','RSI', 'MACD','MACDh', 'MACDs']]


cols = data.columns

# %%
data.head(50)
# Out:
#                            Up_Down  Adj Close   log_ret    200ema     50ema  \
# 2020-07-31 08:00:00+01:00      0.0    0.90392 -0.002197  0.905160  0.905636
# 2020-07-31 09:00:00+01:00      0.0    0.90326 -0.000730  0.905096  0.905543
# 2020-07-31 10:00:00+01:00      0.0    0.90250 -0.000841  0.905011  0.905424
# 2020-07-31 11:00:00+01:00      0.0    0.90210 -0.000443  0.904917  0.905293
# 2020-07-31 12:00:00+01:00      0.0    0.90090 -0.001330  0.904791  0.905121
# 2020-07-31 13:00:00+01:00      0.0    0.90030 -0.000666  0.904652  0.904932
# 2020-07-31 14:00:00+01:00      1.0    0.89833 -0.002188  0.904461  0.904673
# 2020-07-31 15:00:00+01:00      0.0    0.90135  0.003362  0.904369  0.904543
# 2020-07-31 16:00:00+01:00      1.0    0.90009 -0.001398  0.904245  0.904368
# 2020-07-31 17:00:00+01:00      0.0    0.90013  0.000044  0.904128  0.904202
# 2020-07-31 18:00:00+01:00      1.0    0.89937 -0.000844  0.903995  0.904013
# 2020-07-31 19:00:00+01:00      1.0    0.89953  0.000178  0.903872  0.903837
# 2020-07-31 20:00:00+01:00      0.0    0.89977  0.000267  0.903762  0.903677
# 2020-07-31 21:00:00+01:00      0.0    0.89973 -0.000044  0.903655  0.903522
# 2020-07-31 22:00:00+01:00      1.0    0.89973  0.000000  0.903552  0.903374
# 2020-07-31 23:00:00+01:00      0.0    0.89977  0.000044  0.903455  0.903232
# 2020-08-03 00:00:00+01:00      0.0    0.89931 -0.000511  0.903350  0.903079
# 2020-08-03 01:00:00+01:00      1.0    0.89890 -0.000456  0.903239  0.902915
# 2020-08-03 02:00:00+01:00      1.0    0.89893  0.000033  0.903134  0.902758
# 2020-08-03 03:00:00+01:00      0.0    0.89945  0.000578  0.903045  0.902629
# 2020-08-03 04:00:00+01:00      1.0    0.89910 -0.000389  0.902951  0.902490
# 2020-08-03 05:00:00+01:00      0.0    0.89940  0.000334  0.902867  0.902369
# 2020-08-03 06:00:00+01:00      1.0    0.89925 -0.000167  0.902783  0.902247
# 2020-08-03 07:00:00+01:00      1.0    0.89940  0.000167  0.902706  0.902135
# 2020-08-03 08:00:00+01:00      0.0    0.89960  0.000222  0.902635  0.902036
# 2020-08-03 09:00:00+01:00      1.0    0.89905 -0.000611  0.902555  0.901919
# 2020-08-03 10:00:00+01:00      1.0    0.90030  0.001390  0.902506  0.901855
# 2020-08-03 11:00:00+01:00      0.0    0.90084  0.000600  0.902469  0.901815
# 2020-08-03 12:00:00+01:00      0.0    0.89969 -0.001277  0.902409  0.901732
# 2020-08-03 13:00:00+01:00      1.0    0.89888 -0.000900  0.902334  0.901620
# 2020-08-03 14:00:00+01:00      1.0    0.90074  0.002069  0.902301  0.901586
# 2020-08-03 15:00:00+01:00      0.0    0.90076  0.000022  0.902269  0.901553
# 2020-08-03 16:00:00+01:00      0.0    0.90018 -0.000644  0.902226  0.901499
# 2020-08-03 17:00:00+01:00      0.0    0.89967 -0.000567  0.902174  0.901428
# 2020-08-03 18:00:00+01:00      0.0    0.89950 -0.000189  0.902120  0.901352
# 2020-08-03 19:00:00+01:00      1.0    0.89926 -0.000267  0.902063  0.901270
# 2020-08-03 20:00:00+01:00      0.0    0.89951  0.000278  0.902012  0.901201
# 2020-08-03 21:00:00+01:00      0.0    0.89945 -0.000067  0.901962  0.901132
# 2020-08-03 22:00:00+01:00      1.0    0.89927 -0.000200  0.901910  0.901059
# 2020-08-03 23:00:00+01:00      0.0    0.89930  0.000033  0.901860  0.900990
# 2020-08-04 00:00:00+01:00      1.0    0.89915 -0.000167  0.901808  0.900918
# 2020-08-04 01:00:00+01:00      1.0    0.89936  0.000234  0.901762  0.900857
# 2020-08-04 02:00:00+01:00      1.0    0.89937  0.000011  0.901717  0.900799
# 2020-08-04 03:00:00+01:00      1.0    0.89946  0.000100  0.901675  0.900746
# 2020-08-04 04:00:00+01:00      1.0    0.89995  0.000545  0.901644  0.900715
# 2020-08-04 05:00:00+01:00      1.0    0.90000  0.000056  0.901614  0.900687
# 2020-08-04 06:00:00+01:00      1.0    0.90014  0.000156  0.901587  0.900666
# 2020-08-04 07:00:00+01:00      1.0    0.90048  0.000378  0.901567  0.900658
# 2020-08-04 08:00:00+01:00      1.0    0.90092  0.000489  0.901556  0.900669
# 2020-08-04 09:00:00+01:00      1.0    0.90231  0.001543  0.901569  0.900733
#
#                               20ema        RSI      MACD     MACDh     MACDs
# 2020-07-31 08:00:00+01:00  0.905117  39.013859 -0.000109  0.000145 -0.000254
# 2020-07-31 09:00:00+01:00  0.904940  35.076826 -0.000251  0.000003 -0.000253
# 2020-07-31 10:00:00+01:00  0.904708  31.175381 -0.000420 -0.000133 -0.000287
# 2020-07-31 11:00:00+01:00  0.904460  29.326823 -0.000579 -0.000234 -0.000345
# 2020-07-31 12:00:00+01:00  0.904121  24.611329 -0.000793 -0.000358 -0.000435
# 2020-07-31 13:00:00+01:00  0.903757  22.650361 -0.001000 -0.000452 -0.000548
# 2020-07-31 14:00:00+01:00  0.903240  17.671462 -0.001307 -0.000608 -0.000700
# 2020-07-31 15:00:00+01:00  0.903060  39.592820 -0.001292 -0.000474 -0.000818
# 2020-07-31 16:00:00+01:00  0.902777  35.362129 -0.001367 -0.000439 -0.000928
# 2020-07-31 17:00:00+01:00  0.902525  35.597363 -0.001406 -0.000382 -0.001023
# 2020-07-31 18:00:00+01:00  0.902224  33.130135 -0.001481 -0.000366 -0.001115
# 2020-07-31 19:00:00+01:00  0.901968  34.164582 -0.001511 -0.000317 -0.001194
# 2020-07-31 20:00:00+01:00  0.901759  35.770040 -0.001498 -0.000243 -0.001255
# 2020-07-31 21:00:00+01:00  0.901565  35.614197 -0.001473 -0.000175 -0.001299
# 2020-07-31 22:00:00+01:00  0.901391  35.614197 -0.001437 -0.000111 -0.001326
# 2020-07-31 23:00:00+01:00  0.901236  35.937894 -0.001390 -0.000051 -0.001339
# 2020-08-03 00:00:00+01:00  0.901053  33.831054 -0.001373 -0.000027 -0.001346
# 2020-08-03 01:00:00+01:00  0.900848  32.028764 -0.001378 -0.000025 -0.001352
# 2020-08-03 02:00:00+01:00  0.900665  32.313278 -0.001363 -0.000008 -0.001354
# 2020-08-03 03:00:00+01:00  0.900549  37.212427 -0.001294  0.000048 -0.001342
# 2020-08-03 04:00:00+01:00  0.900411  35.357390 -0.001253  0.000071 -0.001324
# 2020-08-03 05:00:00+01:00  0.900315  38.201010 -0.001183  0.000113 -0.001296
# 2020-08-03 06:00:00+01:00  0.900214  37.316914 -0.001127  0.000135 -0.001262
# 2020-08-03 07:00:00+01:00  0.900136  38.841205 -0.001058  0.000163 -0.001222
# 2020-08-03 08:00:00+01:00  0.900085  40.904657 -0.000976  0.000196 -0.001172
# 2020-08-03 09:00:00+01:00  0.899986  37.189120 -0.000944  0.000182 -0.001127
# 2020-08-03 10:00:00+01:00  0.900016  48.613117 -0.000809  0.000254 -0.001063
# 2020-08-03 11:00:00+01:00  0.900095  52.621673 -0.000651  0.000330 -0.000981
# 2020-08-03 12:00:00+01:00  0.900056  44.635436 -0.000611  0.000296 -0.000907
# 2020-08-03 13:00:00+01:00  0.899944  40.027695 -0.000638  0.000215 -0.000853
# 2020-08-03 14:00:00+01:00  0.900020  52.224561 -0.000503  0.000280 -0.000783
# 2020-08-03 15:00:00+01:00  0.900090  52.336627 -0.000390  0.000314 -0.000705
# 2020-08-03 16:00:00+01:00  0.900099  48.758800 -0.000344  0.000289 -0.000632
# 2020-08-03 17:00:00+01:00  0.900058  45.794482 -0.000344  0.000231 -0.000575
# 2020-08-03 18:00:00+01:00  0.900005  44.816407 -0.000354  0.000177 -0.000530
# 2020-08-03 19:00:00+01:00  0.899934  43.406688 -0.000376  0.000123 -0.000500
# 2020-08-03 20:00:00+01:00  0.899894  45.335697 -0.000370  0.000104 -0.000474
# 2020-08-03 21:00:00+01:00  0.899851  44.939710 -0.000366  0.000087 -0.000452
# 2020-08-03 22:00:00+01:00  0.899796  43.706741 -0.000372  0.000064 -0.000436
# 2020-08-03 23:00:00+01:00  0.899749  43.982413 -0.000371  0.000052 -0.000423
# 2020-08-04 00:00:00+01:00  0.899692  42.852008 -0.000378  0.000036 -0.000414
# 2020-08-04 01:00:00+01:00  0.899660  44.984213 -0.000362  0.000042 -0.000404
# 2020-08-04 02:00:00+01:00  0.899633  45.089425 -0.000344  0.000047 -0.000392
# 2020-08-04 03:00:00+01:00  0.899616  46.087402 -0.000320  0.000058 -0.000377
# 2020-08-04 04:00:00+01:00  0.899648  51.279130 -0.000258  0.000096 -0.000353
# 2020-08-04 05:00:00+01:00  0.899681  51.788782 -0.000202  0.000121 -0.000323
# 2020-08-04 06:00:00+01:00  0.899725  53.264585 -0.000145  0.000142 -0.000288
# 2020-08-04 07:00:00+01:00  0.899797  56.728474 -0.000072  0.000173 -0.000244
# 2020-08-04 08:00:00+01:00  0.899904  60.779881  0.000022  0.000213 -0.000191
# 2020-08-04 09:00:00+01:00  0.900133  70.254847  0.000206  0.000317 -0.000112

# %%
data.reset_index(inplace=True)
data.drop(columns=data.columns[0], inplace=True)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# ## Preparacion datos para el LSTM

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6747 entries, 0 to 6746
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Up_Down    6747 non-null   float64
#  1   Adj Close  6747 non-null   float64
#  2   log_ret    6747 non-null   float64
#  3   200ema     6747 non-null   float64
#  4   50ema      6747 non-null   float64
#  5   20ema      6747 non-null   float64
#  6   RSI        6747 non-null   float64
#  7   MACD       6747 non-null   float64
#  8   MACDh      6747 non-null   float64
#  9   MACDs      6747 non-null   float64
# dtypes: float64(10)
# memory usage: 527.2 KB

# %%
#Convertimos todas las columnas a valor numerico
data = data.apply(pd.to_numeric)


#Escalamos los valores con un MinMaxScaler

data['200ema'] = data['200ema'].pct_change()
data['50ema'] = data['50ema'].pct_change()
data['20ema'] = data['20ema'].pct_change()

data.dropna(inplace=True)

values = data.values

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

values = scaled

#Dividimos los datos entre train y test
train, val = train_test_split(values, test_size=0.2, shuffle=False)

#Dividimos datos validation entre validation y test
val, test = train_test_split(val, test_size=0.5, shuffle=False)

#Separamos los inputs de los outputs
train_X, train_y = train[:, 1:], train[:,0]
val_X, val_y = val[:, 1:], val[:,0]
test_X, test_y = test[:, 1:], test[:, 0]


#Generamos el reshape para poder incluir los valores en el modelo LSTM
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, val_X.shape, val_y.shape, test_X.shape, test_y.shape)
# Out:
# (5396, 1, 9) (5396,) (675, 1, 9) (675,) (675, 1, 9) (675,)

# %% [markdown]
# ## Creamos el modelo

# %%
#Generamos arquitectura del modelo
model = Sequential()

model.add(Dense(128, activation='LeakyReLU', kernel_initializer='he_uniform' ,input_shape=(train_X.shape[1], train_X.shape[2])))

model.add(LSTM(256, activation='LeakyReLU', return_sequences=True))
model.add(BatchNormalization())

model.add(LSTM(256, activation='LeakyReLU', return_sequences=True))
model.add(BatchNormalization())



model.add(Dense(128, activation='LeakyReLU'))



model.add(Dense(1, activation='sigmoid'))

# %%
int(train_X.shape[0]/2)
# Out:
# 2698

# %%
epochs = 200
train_size = train_X.shape[0]
batch_size = int(train_X.shape[0]/2)

initial_learning_rate = 1.1
final_learning_rate = 0.1
learning_rate_decay_factor = (final_learning_rate / initial_learning_rate)**(1/epochs)
steps_per_epoch = int(train_size/batch_size)

lr_schedule = ExponentialDecay(
                initial_learning_rate=initial_learning_rate,
                decay_steps=steps_per_epoch,
                decay_rate=learning_rate_decay_factor,
                staircase=True)

opt = Adam()

# %%
model.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1, 128)            1280
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 256)            394240
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1, 256)            1024
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 1, 256)            525312
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1, 256)            1024
# _________________________________________________________________
# dense_1 (Dense)              (None, 1, 128)            32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 1, 1)              129
# =================================================================
# Total params: 955,905
# Trainable params: 954,881
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
#Entrenamos el modelo
history = model.fit(train_X, train_y, epochs=epochs, batch_size = batch_size, validation_data=(val_X, val_y), verbose=2)
# Out:
# Epoch 1/200
# 2/2 - 5s - loss: 0.9642 - accuracy: 0.4959 - val_loss: 0.6924 - val_accuracy: 0.5378
# Epoch 2/200
# 2/2 - 1s - loss: 0.7758 - accuracy: 0.5193 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 3/200
# 2/2 - 1s - loss: 0.7864 - accuracy: 0.5056 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 4/200
# 2/2 - 1s - loss: 0.7207 - accuracy: 0.4983 - val_loss: 0.6928 - val_accuracy: 0.5378
# Epoch 5/200
# 2/2 - 1s - loss: 0.7295 - accuracy: 0.5096 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 6/200
# 2/2 - 1s - loss: 0.7008 - accuracy: 0.5176 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 7/200
# 2/2 - 1s - loss: 0.7047 - accuracy: 0.5085 - val_loss: 0.6928 - val_accuracy: 0.5378
# Epoch 8/200
# 2/2 - 1s - loss: 0.6975 - accuracy: 0.5154 - val_loss: 0.6927 - val_accuracy: 0.5378
# Epoch 9/200
# 2/2 - 1s - loss: 0.6917 - accuracy: 0.5298 - val_loss: 0.6927 - val_accuracy: 0.5378
# Epoch 10/200
# 2/2 - 1s - loss: 0.6940 - accuracy: 0.5285 - val_loss: 0.6928 - val_accuracy: 0.5378
# Epoch 11/200
# 2/2 - 1s - loss: 0.6877 - accuracy: 0.5402 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 12/200
# 2/2 - 1s - loss: 0.6879 - accuracy: 0.5424 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 13/200
# 2/2 - 1s - loss: 0.6872 - accuracy: 0.5443 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 14/200
# 2/2 - 1s - loss: 0.6854 - accuracy: 0.5460 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 15/200
# 2/2 - 1s - loss: 0.6854 - accuracy: 0.5486 - val_loss: 0.6928 - val_accuracy: 0.5378
# Epoch 16/200
# 2/2 - 1s - loss: 0.6843 - accuracy: 0.5487 - val_loss: 0.6928 - val_accuracy: 0.5378
# Epoch 17/200
# 2/2 - 1s - loss: 0.6820 - accuracy: 0.5621 - val_loss: 0.6928 - val_accuracy: 0.5378
# Epoch 18/200
# 2/2 - 1s - loss: 0.6820 - accuracy: 0.5617 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 19/200
# 2/2 - 1s - loss: 0.6807 - accuracy: 0.5643 - val_loss: 0.6930 - val_accuracy: 0.5378
# Epoch 20/200
# 2/2 - 1s - loss: 0.6799 - accuracy: 0.5650 - val_loss: 0.6930 - val_accuracy: 0.5378
# Epoch 21/200
# 2/2 - 1s - loss: 0.6796 - accuracy: 0.5662 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 22/200
# 2/2 - 1s - loss: 0.6788 - accuracy: 0.5663 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 23/200
# 2/2 - 1s - loss: 0.6784 - accuracy: 0.5743 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 24/200
# 2/2 - 1s - loss: 0.6773 - accuracy: 0.5815 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 25/200
# 2/2 - 1s - loss: 0.6768 - accuracy: 0.5806 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 26/200
# 2/2 - 1s - loss: 0.6757 - accuracy: 0.5786 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 27/200
# 2/2 - 1s - loss: 0.6757 - accuracy: 0.5797 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 28/200
# 2/2 - 1s - loss: 0.6747 - accuracy: 0.5856 - val_loss: 0.6929 - val_accuracy: 0.5378
# Epoch 29/200
# 2/2 - 1s - loss: 0.6742 - accuracy: 0.5893 - val_loss: 0.6930 - val_accuracy: 0.5378
# Epoch 30/200
# 2/2 - 1s - loss: 0.6736 - accuracy: 0.5860 - val_loss: 0.6930 - val_accuracy: 0.5378
# Epoch 31/200
# 2/2 - 1s - loss: 0.6736 - accuracy: 0.5880 - val_loss: 0.6931 - val_accuracy: 0.5393
# Epoch 32/200
# 2/2 - 1s - loss: 0.6725 - accuracy: 0.5973 - val_loss: 0.6931 - val_accuracy: 0.5304
# Epoch 33/200
# 2/2 - 1s - loss: 0.6725 - accuracy: 0.5891 - val_loss: 0.6931 - val_accuracy: 0.5378
# Epoch 34/200
# 2/2 - 1s - loss: 0.6716 - accuracy: 0.5930 - val_loss: 0.6931 - val_accuracy: 0.4978
# Epoch 35/200
# 2/2 - 1s - loss: 0.6708 - accuracy: 0.5949 - val_loss: 0.6932 - val_accuracy: 0.4756
# Epoch 36/200
# 2/2 - 1s - loss: 0.6704 - accuracy: 0.5897 - val_loss: 0.6932 - val_accuracy: 0.4681
# Epoch 37/200
# 2/2 - 1s - loss: 0.6698 - accuracy: 0.5958 - val_loss: 0.6933 - val_accuracy: 0.4607
# Epoch 38/200
# 2/2 - 1s - loss: 0.6690 - accuracy: 0.5943 - val_loss: 0.6934 - val_accuracy: 0.4622
# Epoch 39/200
# 2/2 - 1s - loss: 0.6684 - accuracy: 0.5984 - val_loss: 0.6935 - val_accuracy: 0.4622
# Epoch 40/200
# 2/2 - 1s - loss: 0.6684 - accuracy: 0.5904 - val_loss: 0.6935 - val_accuracy: 0.4622
# Epoch 41/200
# 2/2 - 1s - loss: 0.6670 - accuracy: 0.5956 - val_loss: 0.6935 - val_accuracy: 0.4622
# Epoch 42/200
# 2/2 - 1s - loss: 0.6670 - accuracy: 0.5986 - val_loss: 0.6936 - val_accuracy: 0.4622
# Epoch 43/200
# 2/2 - 1s - loss: 0.6660 - accuracy: 0.6043 - val_loss: 0.6937 - val_accuracy: 0.4622
# Epoch 44/200
# 2/2 - 1s - loss: 0.6654 - accuracy: 0.6019 - val_loss: 0.6938 - val_accuracy: 0.4622
# Epoch 45/200
# 2/2 - 1s - loss: 0.6644 - accuracy: 0.6008 - val_loss: 0.6938 - val_accuracy: 0.4622
# Epoch 46/200
# 2/2 - 1s - loss: 0.6640 - accuracy: 0.6043 - val_loss: 0.6939 - val_accuracy: 0.4622
# Epoch 47/200
# 2/2 - 1s - loss: 0.6637 - accuracy: 0.6049 - val_loss: 0.6939 - val_accuracy: 0.4622
# Epoch 48/200
# 2/2 - 1s - loss: 0.6641 - accuracy: 0.6006 - val_loss: 0.6940 - val_accuracy: 0.4622
# Epoch 49/200
# 2/2 - 1s - loss: 0.6621 - accuracy: 0.6027 - val_loss: 0.6940 - val_accuracy: 0.4622
# Epoch 50/200
# 2/2 - 1s - loss: 0.6618 - accuracy: 0.6054 - val_loss: 0.6941 - val_accuracy: 0.4622
# Epoch 51/200
# 2/2 - 1s - loss: 0.6617 - accuracy: 0.6036 - val_loss: 0.6942 - val_accuracy: 0.4622
# Epoch 52/200
# 2/2 - 1s - loss: 0.6607 - accuracy: 0.6066 - val_loss: 0.6942 - val_accuracy: 0.4622
# Epoch 53/200
# 2/2 - 1s - loss: 0.6606 - accuracy: 0.6101 - val_loss: 0.6943 - val_accuracy: 0.4622
# Epoch 54/200
# 2/2 - 1s - loss: 0.6601 - accuracy: 0.6095 - val_loss: 0.6945 - val_accuracy: 0.4622
# Epoch 55/200
# 2/2 - 1s - loss: 0.6594 - accuracy: 0.6042 - val_loss: 0.6945 - val_accuracy: 0.4622
# Epoch 56/200
# 2/2 - 1s - loss: 0.6588 - accuracy: 0.6080 - val_loss: 0.6946 - val_accuracy: 0.4622
# Epoch 57/200
# 2/2 - 1s - loss: 0.6557 - accuracy: 0.6119 - val_loss: 0.6945 - val_accuracy: 0.4622
# Epoch 58/200
# 2/2 - 1s - loss: 0.6575 - accuracy: 0.6056 - val_loss: 0.6946 - val_accuracy: 0.4622
# Epoch 59/200
# 2/2 - 1s - loss: 0.6583 - accuracy: 0.6105 - val_loss: 0.6948 - val_accuracy: 0.4622
# Epoch 60/200
# 2/2 - 1s - loss: 0.6557 - accuracy: 0.6179 - val_loss: 0.6948 - val_accuracy: 0.4622
# Epoch 61/200
# 2/2 - 1s - loss: 0.6555 - accuracy: 0.6112 - val_loss: 0.6949 - val_accuracy: 0.4622
# Epoch 62/200
# 2/2 - 1s - loss: 0.6534 - accuracy: 0.6173 - val_loss: 0.6950 - val_accuracy: 0.4622
# Epoch 63/200
# 2/2 - 1s - loss: 0.6531 - accuracy: 0.6160 - val_loss: 0.6951 - val_accuracy: 0.4622
# Epoch 64/200
# 2/2 - 1s - loss: 0.6512 - accuracy: 0.6232 - val_loss: 0.6952 - val_accuracy: 0.4622
# Epoch 65/200
# 2/2 - 1s - loss: 0.6510 - accuracy: 0.6234 - val_loss: 0.6951 - val_accuracy: 0.4622
# Epoch 66/200
# 2/2 - 1s - loss: 0.6502 - accuracy: 0.6216 - val_loss: 0.6951 - val_accuracy: 0.4622
# Epoch 67/200
# 2/2 - 1s - loss: 0.6483 - accuracy: 0.6251 - val_loss: 0.6952 - val_accuracy: 0.4622
# Epoch 68/200
# 2/2 - 1s - loss: 0.6492 - accuracy: 0.6206 - val_loss: 0.6953 - val_accuracy: 0.4622
# Epoch 69/200
# 2/2 - 1s - loss: 0.6465 - accuracy: 0.6288 - val_loss: 0.6955 - val_accuracy: 0.4622
# Epoch 70/200
# 2/2 - 1s - loss: 0.6471 - accuracy: 0.6275 - val_loss: 0.6955 - val_accuracy: 0.4622
# Epoch 71/200
# 2/2 - 1s - loss: 0.6469 - accuracy: 0.6268 - val_loss: 0.6954 - val_accuracy: 0.4622
# Epoch 72/200
# 2/2 - 1s - loss: 0.6452 - accuracy: 0.6260 - val_loss: 0.6957 - val_accuracy: 0.4622
# Epoch 73/200
# 2/2 - 1s - loss: 0.6470 - accuracy: 0.6208 - val_loss: 0.6957 - val_accuracy: 0.4622
# Epoch 74/200
# 2/2 - 1s - loss: 0.6450 - accuracy: 0.6240 - val_loss: 0.6957 - val_accuracy: 0.4622
# Epoch 75/200
# 2/2 - 1s - loss: 0.6445 - accuracy: 0.6232 - val_loss: 0.6959 - val_accuracy: 0.4622
# Epoch 76/200
# 2/2 - 1s - loss: 0.6434 - accuracy: 0.6268 - val_loss: 0.6960 - val_accuracy: 0.4622
# Epoch 77/200
# 2/2 - 1s - loss: 0.6440 - accuracy: 0.6229 - val_loss: 0.6962 - val_accuracy: 0.4622
# Epoch 78/200
# 2/2 - 1s - loss: 0.6407 - accuracy: 0.6305 - val_loss: 0.6965 - val_accuracy: 0.4622
# Epoch 79/200
# 2/2 - 1s - loss: 0.6406 - accuracy: 0.6244 - val_loss: 0.6966 - val_accuracy: 0.4622
# Epoch 80/200
# 2/2 - 1s - loss: 0.6400 - accuracy: 0.6338 - val_loss: 0.6967 - val_accuracy: 0.4622
# Epoch 81/200
# 2/2 - 1s - loss: 0.6396 - accuracy: 0.6312 - val_loss: 0.6966 - val_accuracy: 0.4622
# Epoch 82/200
# 2/2 - 1s - loss: 0.6393 - accuracy: 0.6277 - val_loss: 0.6965 - val_accuracy: 0.4622
# Epoch 83/200
# 2/2 - 1s - loss: 0.6390 - accuracy: 0.6307 - val_loss: 0.6969 - val_accuracy: 0.4622
# Epoch 84/200
# 2/2 - 1s - loss: 0.6377 - accuracy: 0.6331 - val_loss: 0.6969 - val_accuracy: 0.4622
# Epoch 85/200
# 2/2 - 1s - loss: 0.6362 - accuracy: 0.6312 - val_loss: 0.6973 - val_accuracy: 0.4622
# Epoch 86/200
# 2/2 - 1s - loss: 0.6349 - accuracy: 0.6334 - val_loss: 0.6972 - val_accuracy: 0.4622
# Epoch 87/200
# 2/2 - 1s - loss: 0.6361 - accuracy: 0.6227 - val_loss: 0.6980 - val_accuracy: 0.4622
# Epoch 88/200
# 2/2 - 1s - loss: 0.6380 - accuracy: 0.6286 - val_loss: 0.6980 - val_accuracy: 0.4622
# Epoch 89/200
# 2/2 - 1s - loss: 0.6363 - accuracy: 0.6256 - val_loss: 0.6979 - val_accuracy: 0.4622
# Epoch 90/200
# 2/2 - 1s - loss: 0.6401 - accuracy: 0.6297 - val_loss: 0.6977 - val_accuracy: 0.4622
# Epoch 91/200
# 2/2 - 1s - loss: 0.6338 - accuracy: 0.6256 - val_loss: 0.6981 - val_accuracy: 0.4622
# Epoch 92/200
# 2/2 - 1s - loss: 0.6340 - accuracy: 0.6307 - val_loss: 0.6984 - val_accuracy: 0.4622
# Epoch 93/200
# 2/2 - 1s - loss: 0.6363 - accuracy: 0.6314 - val_loss: 0.6984 - val_accuracy: 0.4622
# Epoch 94/200
# 2/2 - 1s - loss: 0.6357 - accuracy: 0.6273 - val_loss: 0.6984 - val_accuracy: 0.4622
# Epoch 95/200
# 2/2 - 1s - loss: 0.6356 - accuracy: 0.6245 - val_loss: 0.6977 - val_accuracy: 0.4622
# Epoch 96/200
# 2/2 - 1s - loss: 0.6339 - accuracy: 0.6334 - val_loss: 0.6985 - val_accuracy: 0.4622
# Epoch 97/200
# 2/2 - 1s - loss: 0.6306 - accuracy: 0.6442 - val_loss: 0.6983 - val_accuracy: 0.4622
# Epoch 98/200
# 2/2 - 1s - loss: 0.6308 - accuracy: 0.6331 - val_loss: 0.6988 - val_accuracy: 0.4622
# Epoch 99/200
# 2/2 - 1s - loss: 0.6284 - accuracy: 0.6336 - val_loss: 0.6987 - val_accuracy: 0.4622
# Epoch 100/200
# 2/2 - 1s - loss: 0.6224 - accuracy: 0.6510 - val_loss: 0.6981 - val_accuracy: 0.4622
# Epoch 101/200
# 2/2 - 1s - loss: 0.6278 - accuracy: 0.6453 - val_loss: 0.6989 - val_accuracy: 0.4622
# Epoch 102/200
# 2/2 - 1s - loss: 0.6219 - accuracy: 0.6494 - val_loss: 0.6991 - val_accuracy: 0.4622
# Epoch 103/200
# 2/2 - 1s - loss: 0.6202 - accuracy: 0.6496 - val_loss: 0.6987 - val_accuracy: 0.4622
# Epoch 104/200
# 2/2 - 1s - loss: 0.6201 - accuracy: 0.6477 - val_loss: 0.6987 - val_accuracy: 0.4622
# Epoch 105/200
# 2/2 - 1s - loss: 0.6188 - accuracy: 0.6497 - val_loss: 0.6993 - val_accuracy: 0.4622
# Epoch 106/200
# 2/2 - 1s - loss: 0.6202 - accuracy: 0.6553 - val_loss: 0.6994 - val_accuracy: 0.4622
# Epoch 107/200
# 2/2 - 1s - loss: 0.6167 - accuracy: 0.6533 - val_loss: 0.7000 - val_accuracy: 0.4622
# Epoch 108/200
# 2/2 - 1s - loss: 0.6159 - accuracy: 0.6507 - val_loss: 0.6996 - val_accuracy: 0.4622
# Epoch 109/200
# 2/2 - 1s - loss: 0.6165 - accuracy: 0.6494 - val_loss: 0.7005 - val_accuracy: 0.4622
# Epoch 110/200
# 2/2 - 1s - loss: 0.6147 - accuracy: 0.6544 - val_loss: 0.7002 - val_accuracy: 0.4622
# Epoch 111/200
# 2/2 - 1s - loss: 0.6152 - accuracy: 0.6505 - val_loss: 0.7012 - val_accuracy: 0.4622
# Epoch 112/200
# 2/2 - 1s - loss: 0.6153 - accuracy: 0.6566 - val_loss: 0.7008 - val_accuracy: 0.4622
# Epoch 113/200
# 2/2 - 1s - loss: 0.6187 - accuracy: 0.6473 - val_loss: 0.7016 - val_accuracy: 0.4622
# Epoch 114/200
# 2/2 - 1s - loss: 0.6166 - accuracy: 0.6575 - val_loss: 0.7008 - val_accuracy: 0.4622
# Epoch 115/200
# 2/2 - 1s - loss: 0.6138 - accuracy: 0.6520 - val_loss: 0.7028 - val_accuracy: 0.4622
# Epoch 116/200
# 2/2 - 1s - loss: 0.6190 - accuracy: 0.6503 - val_loss: 0.7027 - val_accuracy: 0.4622
# Epoch 117/200
# 2/2 - 1s - loss: 0.6115 - accuracy: 0.6557 - val_loss: 0.7021 - val_accuracy: 0.4622
# Epoch 118/200
# 2/2 - 1s - loss: 0.6097 - accuracy: 0.6596 - val_loss: 0.7018 - val_accuracy: 0.4622
# Epoch 119/200
# 2/2 - 1s - loss: 0.6196 - accuracy: 0.6505 - val_loss: 0.7023 - val_accuracy: 0.4622
# Epoch 120/200
# 2/2 - 1s - loss: 0.6119 - accuracy: 0.6518 - val_loss: 0.7040 - val_accuracy: 0.4622
# Epoch 121/200
# 2/2 - 1s - loss: 0.6087 - accuracy: 0.6546 - val_loss: 0.7026 - val_accuracy: 0.4622
# Epoch 122/200
# 2/2 - 1s - loss: 0.6043 - accuracy: 0.6579 - val_loss: 0.7032 - val_accuracy: 0.4622
# Epoch 123/200
# 2/2 - 1s - loss: 0.6097 - accuracy: 0.6599 - val_loss: 0.7026 - val_accuracy: 0.4622
# Epoch 124/200
# 2/2 - 1s - loss: 0.6028 - accuracy: 0.6657 - val_loss: 0.7045 - val_accuracy: 0.4622
# Epoch 125/200
# 2/2 - 1s - loss: 0.6015 - accuracy: 0.6672 - val_loss: 0.7029 - val_accuracy: 0.4622
# Epoch 126/200
# 2/2 - 1s - loss: 0.6006 - accuracy: 0.6586 - val_loss: 0.7038 - val_accuracy: 0.4622
# Epoch 127/200
# 2/2 - 1s - loss: 0.6004 - accuracy: 0.6657 - val_loss: 0.7034 - val_accuracy: 0.4622
# Epoch 128/200
# 2/2 - 1s - loss: 0.6001 - accuracy: 0.6601 - val_loss: 0.7050 - val_accuracy: 0.4622
# Epoch 129/200
# 2/2 - 1s - loss: 0.6032 - accuracy: 0.6677 - val_loss: 0.7040 - val_accuracy: 0.4622
# Epoch 130/200
# 2/2 - 1s - loss: 0.6029 - accuracy: 0.6521 - val_loss: 0.7052 - val_accuracy: 0.4622
# Epoch 131/200
# 2/2 - 1s - loss: 0.5971 - accuracy: 0.6662 - val_loss: 0.7048 - val_accuracy: 0.4622
# Epoch 132/200
# 2/2 - 1s - loss: 0.5983 - accuracy: 0.6696 - val_loss: 0.7047 - val_accuracy: 0.4622
# Epoch 133/200
# 2/2 - 1s - loss: 0.5988 - accuracy: 0.6659 - val_loss: 0.7068 - val_accuracy: 0.4622
# Epoch 134/200
# 2/2 - 1s - loss: 0.5930 - accuracy: 0.6783 - val_loss: 0.7054 - val_accuracy: 0.4622
# Epoch 135/200
# 2/2 - 1s - loss: 0.5949 - accuracy: 0.6774 - val_loss: 0.7067 - val_accuracy: 0.4622
# Epoch 136/200
# 2/2 - 1s - loss: 0.5913 - accuracy: 0.6735 - val_loss: 0.7048 - val_accuracy: 0.4637
# Epoch 137/200
# 2/2 - 1s - loss: 0.5960 - accuracy: 0.6686 - val_loss: 0.7078 - val_accuracy: 0.4622
# Epoch 138/200
# 2/2 - 1s - loss: 0.5917 - accuracy: 0.6686 - val_loss: 0.7059 - val_accuracy: 0.4637
# Epoch 139/200
# 2/2 - 1s - loss: 0.5940 - accuracy: 0.6701 - val_loss: 0.7075 - val_accuracy: 0.4622
# Epoch 140/200
# 2/2 - 1s - loss: 0.5898 - accuracy: 0.6762 - val_loss: 0.7078 - val_accuracy: 0.4637
# Epoch 141/200
# 2/2 - 1s - loss: 0.5896 - accuracy: 0.6761 - val_loss: 0.7062 - val_accuracy: 0.4622
# Epoch 142/200
# 2/2 - 1s - loss: 0.5885 - accuracy: 0.6762 - val_loss: 0.7067 - val_accuracy: 0.4637
# Epoch 143/200
# 2/2 - 1s - loss: 0.5931 - accuracy: 0.6716 - val_loss: 0.7081 - val_accuracy: 0.4637
# Epoch 144/200
# 2/2 - 1s - loss: 0.5893 - accuracy: 0.6774 - val_loss: 0.7078 - val_accuracy: 0.4637
# Epoch 145/200
# 2/2 - 1s - loss: 0.5881 - accuracy: 0.6762 - val_loss: 0.7079 - val_accuracy: 0.4652
# Epoch 146/200
# 2/2 - 1s - loss: 0.5872 - accuracy: 0.6755 - val_loss: 0.7079 - val_accuracy: 0.4622
# Epoch 147/200
# 2/2 - 1s - loss: 0.5845 - accuracy: 0.6762 - val_loss: 0.7087 - val_accuracy: 0.4622
# Epoch 148/200
# 2/2 - 1s - loss: 0.5850 - accuracy: 0.6757 - val_loss: 0.7091 - val_accuracy: 0.4637
# Epoch 149/200
# 2/2 - 1s - loss: 0.5838 - accuracy: 0.6862 - val_loss: 0.7058 - val_accuracy: 0.4593
# Epoch 150/200
# 2/2 - 1s - loss: 0.5802 - accuracy: 0.6862 - val_loss: 0.7066 - val_accuracy: 0.4637
# Epoch 151/200
# 2/2 - 1s - loss: 0.5767 - accuracy: 0.6885 - val_loss: 0.7044 - val_accuracy: 0.4637
# Epoch 152/200
# 2/2 - 1s - loss: 0.5816 - accuracy: 0.6777 - val_loss: 0.7106 - val_accuracy: 0.4637
# Epoch 153/200
# 2/2 - 1s - loss: 0.5782 - accuracy: 0.6842 - val_loss: 0.7081 - val_accuracy: 0.4607
# Epoch 154/200
# 2/2 - 1s - loss: 0.5731 - accuracy: 0.6938 - val_loss: 0.7100 - val_accuracy: 0.4622
# Epoch 155/200
# 2/2 - 1s - loss: 0.5738 - accuracy: 0.6937 - val_loss: 0.7066 - val_accuracy: 0.4593
# Epoch 156/200
# 2/2 - 1s - loss: 0.5727 - accuracy: 0.6940 - val_loss: 0.7091 - val_accuracy: 0.4622
# Epoch 157/200
# 2/2 - 1s - loss: 0.5693 - accuracy: 0.6966 - val_loss: 0.7076 - val_accuracy: 0.4593
# Epoch 158/200
# 2/2 - 1s - loss: 0.5736 - accuracy: 0.6862 - val_loss: 0.7148 - val_accuracy: 0.4652
# Epoch 159/200
# 2/2 - 1s - loss: 0.5821 - accuracy: 0.6803 - val_loss: 0.7077 - val_accuracy: 0.4593
# Epoch 160/200
# 2/2 - 1s - loss: 0.5744 - accuracy: 0.6864 - val_loss: 0.7117 - val_accuracy: 0.4622
# Epoch 161/200
# 2/2 - 1s - loss: 0.5740 - accuracy: 0.6953 - val_loss: 0.7067 - val_accuracy: 0.4622
# Epoch 162/200
# 2/2 - 1s - loss: 0.5728 - accuracy: 0.6850 - val_loss: 0.7129 - val_accuracy: 0.4622
# Epoch 163/200
# 2/2 - 1s - loss: 0.5775 - accuracy: 0.6855 - val_loss: 0.7081 - val_accuracy: 0.4622
# Epoch 164/200
# 2/2 - 1s - loss: 0.5710 - accuracy: 0.6890 - val_loss: 0.7066 - val_accuracy: 0.4607
# Epoch 165/200
# 2/2 - 1s - loss: 0.5669 - accuracy: 0.6935 - val_loss: 0.7074 - val_accuracy: 0.4607
# Epoch 166/200
# 2/2 - 1s - loss: 0.5700 - accuracy: 0.6920 - val_loss: 0.7101 - val_accuracy: 0.4563
# Epoch 167/200
# 2/2 - 1s - loss: 0.5668 - accuracy: 0.6909 - val_loss: 0.7116 - val_accuracy: 0.4607
# Epoch 168/200
# 2/2 - 1s - loss: 0.5651 - accuracy: 0.6966 - val_loss: 0.7081 - val_accuracy: 0.4607
# Epoch 169/200
# 2/2 - 1s - loss: 0.5677 - accuracy: 0.6938 - val_loss: 0.7113 - val_accuracy: 0.4593
# Epoch 170/200
# 2/2 - 1s - loss: 0.5697 - accuracy: 0.6916 - val_loss: 0.7101 - val_accuracy: 0.4607
# Epoch 171/200
# 2/2 - 1s - loss: 0.5573 - accuracy: 0.7027 - val_loss: 0.7096 - val_accuracy: 0.4593
# Epoch 172/200
# 2/2 - 1s - loss: 0.5548 - accuracy: 0.7009 - val_loss: 0.7113 - val_accuracy: 0.4607
# Epoch 173/200
# 2/2 - 1s - loss: 0.5550 - accuracy: 0.7042 - val_loss: 0.7101 - val_accuracy: 0.4607
# Epoch 174/200
# 2/2 - 1s - loss: 0.5587 - accuracy: 0.7007 - val_loss: 0.7124 - val_accuracy: 0.4607
# Epoch 175/200
# 2/2 - 1s - loss: 0.5547 - accuracy: 0.7109 - val_loss: 0.7089 - val_accuracy: 0.4593
# Epoch 176/200
# 2/2 - 1s - loss: 0.5524 - accuracy: 0.7105 - val_loss: 0.7168 - val_accuracy: 0.4622
# Epoch 177/200
# 2/2 - 1s - loss: 0.5497 - accuracy: 0.7129 - val_loss: 0.7112 - val_accuracy: 0.4593
# Epoch 178/200
# 2/2 - 1s - loss: 0.5478 - accuracy: 0.7120 - val_loss: 0.7133 - val_accuracy: 0.4593
# Epoch 179/200
# 2/2 - 1s - loss: 0.5494 - accuracy: 0.7181 - val_loss: 0.7165 - val_accuracy: 0.4593
# Epoch 180/200
# 2/2 - 1s - loss: 0.5504 - accuracy: 0.7085 - val_loss: 0.7098 - val_accuracy: 0.4533
# Epoch 181/200
# 2/2 - 1s - loss: 0.5498 - accuracy: 0.7090 - val_loss: 0.7167 - val_accuracy: 0.4578
# Epoch 182/200
# 2/2 - 1s - loss: 0.5456 - accuracy: 0.7113 - val_loss: 0.7134 - val_accuracy: 0.4607
# Epoch 183/200
# 2/2 - 1s - loss: 0.5418 - accuracy: 0.7181 - val_loss: 0.7165 - val_accuracy: 0.4563
# Epoch 184/200
# 2/2 - 1s - loss: 0.5438 - accuracy: 0.7183 - val_loss: 0.7099 - val_accuracy: 0.4681
# Epoch 185/200
# 2/2 - 1s - loss: 0.5384 - accuracy: 0.7211 - val_loss: 0.7153 - val_accuracy: 0.4548
# Epoch 186/200
# 2/2 - 1s - loss: 0.5395 - accuracy: 0.7213 - val_loss: 0.7165 - val_accuracy: 0.4622
# Epoch 187/200
# 2/2 - 1s - loss: 0.5373 - accuracy: 0.7222 - val_loss: 0.7126 - val_accuracy: 0.4667
# Epoch 188/200
# 2/2 - 1s - loss: 0.5410 - accuracy: 0.7179 - val_loss: 0.7157 - val_accuracy: 0.4607
# Epoch 189/200
# 2/2 - 1s - loss: 0.5345 - accuracy: 0.7229 - val_loss: 0.7132 - val_accuracy: 0.4681
# Epoch 190/200
# 2/2 - 1s - loss: 0.5352 - accuracy: 0.7198 - val_loss: 0.7136 - val_accuracy: 0.4607
# Epoch 191/200
# 2/2 - 1s - loss: 0.5460 - accuracy: 0.7098 - val_loss: 0.7135 - val_accuracy: 0.4681
# Epoch 192/200
# 2/2 - 1s - loss: 0.5388 - accuracy: 0.7142 - val_loss: 0.7152 - val_accuracy: 0.4578
# Epoch 193/200
# 2/2 - 1s - loss: 0.5349 - accuracy: 0.7203 - val_loss: 0.7146 - val_accuracy: 0.4681
# Epoch 194/200
# 2/2 - 1s - loss: 0.5334 - accuracy: 0.7239 - val_loss: 0.7246 - val_accuracy: 0.4578
# Epoch 195/200
# 2/2 - 1s - loss: 0.5545 - accuracy: 0.6959 - val_loss: 0.7120 - val_accuracy: 0.4844
# Epoch 196/200
# 2/2 - 1s - loss: 0.5337 - accuracy: 0.7241 - val_loss: 0.7113 - val_accuracy: 0.4800
# Epoch 197/200
# 2/2 - 1s - loss: 0.5445 - accuracy: 0.7092 - val_loss: 0.7099 - val_accuracy: 0.4904
# Epoch 198/200
# 2/2 - 1s - loss: 0.5366 - accuracy: 0.7228 - val_loss: 0.7170 - val_accuracy: 0.4652
# Epoch 199/200
# 2/2 - 1s - loss: 0.5331 - accuracy: 0.7250 - val_loss: 0.7090 - val_accuracy: 0.5022
# Epoch 200/200
# 2/2 - 1s - loss: 0.5432 - accuracy: 0.7029 - val_loss: 0.7118 - val_accuracy: 0.4815

# %%
#Generamos plot con los resultados
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()

# %%
#Generamos plot con los resultados
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.show()

# %%
# evaluate the model
#loss = model.evaluate(test_X, test_y, verbose=0)
#print('Test Loss: %.5f' % loss)

# %% [markdown]
# ## Resultados con valores de test

# %%
# make a prediction
yhat = model.predict(test_X)

# %%
inv_y, inv_yhat = full_prediction(yhat, test_X, test_y)

# %%
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_y = scaler.inverse_transform(inv_y)


inv_yhat_df = pd.DataFrame(data=inv_yhat, columns=cols)
inv_y_df = pd.DataFrame(data=inv_y, columns=cols)

# %%
res = result(inv_yhat, inv_y)



res['Diff'] = np.where(res['Up_Down_yhat'] == res['Up_Down_y'] , 'Acierto', 'Error')

res['Diff'].value_counts()

print(res['Diff'].value_counts())
print()
per = res['Diff'].value_counts()['Acierto']/(res['Diff'].value_counts()['Acierto']+res['Diff'].value_counts()['Error'])
print(f'% acierto: {per}')
# Out:
# Acierto    342
# Error      333
# Name: Diff, dtype: int64
#
# % acierto: 0.5066666666666667
